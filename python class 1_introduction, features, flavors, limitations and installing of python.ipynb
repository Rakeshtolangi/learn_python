# %%
""""

First class python 


General purpose high level programming language
-> can be used in any area
-> PHP is not general purpose programming langauge

    Python :
        The complete monty pythons cirtus : influence Guido van rossum

-> python as all rounder
    functional Programming: ==> archived from c-programming
-> OOP C++
    object oriented programming from C++
-> Scripting language 
    perl and shell script
-> Modular programming 
    Modula-3
-> syntax similar to c and ABC programming language

-> if you want to built programming langauage using Python
    regular expression
    Multithereading
   
   
# Where can we use Python
-> Desktop App
    tkinter, 
-> Web app
    django,flask,webtopy
->Database apps
->networking
->Games
    c# main language/python/Unity
-> Data analysis
->mL, ai, iot, NN, deep fake



#features of python
simple and easy to learn.
    - very easy syntax
    - reserved keywords or works (33)

Freeware and opensource
    - free of cost
    - free to use

High level programming langauge   # PVM = python virtual maching convert program into low level language
Platform independent
    - multi platform support
portability: environment friendly
Dynamically typed : self identity data type
Interpreted: 
    - python interprered language : PVM will do internally
    - single line executed program
Extensible:
    can be convert other programming code into python
Embedded :
    can be converted python into other programming language.
Huge Library
Huge community support



Limitations of python
- performance
    overcome using pycache
- Mobile apps(KIVI)
    cross platform



Flavors of python:
cpython   (standard flavor of python and recomended)
Jpython (jython)
iron python  (c# or .net)
pypy   (performance enhance)
rubypython     
anaconda python    (large volume of data handling)
"""
